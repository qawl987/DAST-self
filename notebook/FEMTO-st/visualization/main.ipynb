# %%
import sys
sys.path.append('/home/kai/DAST/network')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.load(f'../../../data/10FEMTO/processed_data/Bearing1_1/Bearing1_1_train_X_2560.npy')
y = np.load(f'../../../data/10FEMTO/processed_data/Bearing1_1/Bearing1_1_train_Y.npy')

# %% [markdown]
# ### view HI

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from scipy.optimize import fsolve

FEMTO = '../../../data/10FEMTO/raw_data/Validation_set/'
LEN = 2560

accs = os.listdir(FEMTO+'Bearing3_3')
accs.sort()
accs = [acc for acc in accs if acc.startswith('acc')]
life = len(accs)
print(int(life * 0.82))
def equation(tau, a, T):
    return 1 + np.exp(a) - np.exp((T * tau) + a)

initial_guess = 0
a = 1
T = 15
result = fsolve(equation, initial_guess, args=(a, T))
tau = result[0]
print(f"The solution for τ is: {tau}")
def HI(t):
    return 1 + np.exp(a) - np.exp((t * tau) + a)

rul = [i for i in range(life)]
hi_y = list(map(HI, rul))
min_value = min(hi_y)
max_value = max(hi_y)
normalized_values = [(x - min_value) / (max_value - min_value) for x in hi_y]

plt.figure(figsize=(8.61, 3.09))
plt.xlim(0, 4000)
plt.ylim(0.0, 1.0)
plt.plot(normalized_values, linewidth=2)
plt.axvline(x=life*0.8, color='r', linewidth=1)
plt.axhline(y=0.82, color='r', linewidth=1)
plt.show()

# %% [markdown]
# ## all feature

# %%
for i in range(20):
# Plotting the line chart
    plt.plot(x[:, 0, i], marker='o', markersize=1)
    plt.ylim(min(x[:, 0, i]), max(x[:, 0, i]))
    plt.xlabel('X-axis Label')
    plt.ylabel('Y-axis Label', )
    plt.title(f'Bearing1-1 Feature {i+1}')
    # Display the plot
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_18047/409756697.py in <module>
#       1 for i in range(20):
#       2 # Plotting the line chart
# ----> 3     plt.plot(x[:, 0, i], marker='o', markersize=1)
#       4     plt.ylim(min(x[:, 0, i]), max(x[:, 0, i]))
#       5     plt.xlabel('X-axis Label')
#
# IndexError: index 16 is out of bounds for axis 2 with size 16

# %%
x = np.load(f'../../../data/10FEMTO/processed_data/Bearing1_1/Bearing1_1_train_X_1280.npy')
for i in range(20):
# Plotting the line chart
    plt.plot(x[:, 0, i], marker='o', markersize=1)
    plt.ylim(min(x[:, 0, i]), max(x[:, 0, i]))
    plt.xlabel('X-axis Label')
    plt.ylabel('Y-axis Label', )
    plt.title(f'Bearing1-1 Feature 1280 {i+1}')
    # Display the plot
    plt.show()

# %%
x = np.load(f'../../../data/10FEMTO/processed_data/Bearing1_1/Bearing1_1_train_X_640.npy')
for i in range(16):
# Plotting the line chart
    plt.plot(x[:, 0, i], marker='o', markersize=1)
    plt.ylim(min(x[:, 0, i]), max(x[:, 0, i]))
    plt.xlabel('X-axis Label')
    plt.ylabel('Y-axis Label', )
    plt.title(f'Bearing1-1 Feature 640 {i+1}')
    # Display the plot
    plt.show()

# %% [markdown]
# ## vibration data

# %%
import os
FEMTO = '../../../data/10FEMTO/raw_data/Validation_set/'
folder = 'Bearing1_4_norm'
accs = os.listdir(FEMTO+folder)
accs.sort()
accs = [acc for acc in accs if acc.startswith('acc')]
x_list = []
for stamp, acc in enumerate(accs):
    x = pd.read_csv(f'{FEMTO}/{folder}/{acc}', header=None, sep=',')
    x_avg = x.sum() / len(x)
    x_list.append(x_avg)
x_list = np.array(x_list)
print(x_list.shape)
plt.plot(x_list, marker='o', markersize=1)
plt.ylim(min(x_list), max(x_list))
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label', )
plt.title(f'Bearing1-1 Vibration')
# Display the plot
plt.show()
# Out:
# (1428, 1)

# %%
import os
FEMTO = '../../../data/10FEMTO/raw_data/Validation_set/'
folder = 'Bearing1_1_norm'
accs = os.listdir(FEMTO+folder)
accs.sort()
accs = [acc for acc in accs if acc.startswith('acc')]
x_list = []
for stamp, acc in enumerate(accs):
    x = pd.read_csv(f'{FEMTO}/{folder}/{acc}', header=None, sep=',')
    x_avg = x.sum() / len(x)
    x_list.append(x_avg)
x_list = np.array(x_list)
print(x_list.shape)
plt.plot(x_list, marker='o', markersize=1)
plt.ylim(min(x_list), max(x_list))
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label', )
plt.title(f'Bearing1-1 Vibration')
# Display the plot
plt.show()
# Out:
# (2803, 1)
