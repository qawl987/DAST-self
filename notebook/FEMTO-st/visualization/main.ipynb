# %%
import sys
sys.path.append('/home/kai/DAST/network')
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from typing import List

# %% [markdown]
# ### view HI

# %%
DATASET = 'Bearing1_1'
x = np.load(f'../../../data/10FEMTO/processed_data/{DATASET}/{DATASET}_X_2560.npy')
y = np.load(f'../../../data/10FEMTO/processed_data/{DATASET}/{DATASET}_Y.npy')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from scipy.optimize import fsolve

FEMTO = '../../../data/10FEMTO/raw_data/Validation_set/'
LEN = 2560

accs = os.listdir(FEMTO+'Bearing3_3')
accs.sort()
accs = [acc for acc in accs if acc.startswith('acc')]
life = len(accs)
print(int(life * 0.82))
def equation(tau, a, T):
    return 1 + np.exp(a) - np.exp((T * tau) + a)

initial_guess = 0
a = 1
T = 15
result = fsolve(equation, initial_guess, args=(a, T))
tau = result[0]
print(f"The solution for τ is: {tau}")
def HI(t):
    return 1 + np.exp(a) - np.exp((t * tau) + a)

rul = [i for i in range(life)]
hi_y = list(map(HI, rul))
min_value = min(hi_y)
max_value = max(hi_y)
normalized_values = [(x - min_value) / (max_value - min_value) for x in hi_y]

plt.figure(figsize=(8.61, 3.09))
plt.xlim(0, 4000)
plt.ylim(0.0, 1.0)
plt.plot(normalized_values, linewidth=2)
plt.axvline(x=life*0.8, color='r', linewidth=1)
plt.axhline(y=0.82, color='r', linewidth=1)
plt.show()

# %% [markdown]
# ### all feature

# %%
DATASET = 'Bearing1_1'
x = np.load(f'../../../data/10FEMTO/processed_data/{DATASET}/{DATASET}_X_2560.npy')
y = np.load(f'../../../data/10FEMTO/processed_data/{DATASET}/{DATASET}_Y.npy')
plt.clf()
plt.close('all')
for i in range(20):
# Plotting the line chart
    plt.plot(x[:, 0, i], marker='o', markersize=1)
    plt.ylim(min(x[:, 0, i]), max(x[:, 0, i]))
    plt.xlabel('X-axis Label')
    plt.ylabel('Y-axis Label', )
    plt.title(f'Bearing1-1 Feature {i+1}')
    # Display the plot
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_18813/19378523.py in <module>
#       1 for i in range(20):
#       2 # Plotting the line chart
# ----> 3     plt.plot(x[:, 0, i], marker='o', markersize=1)
#       4     plt.ylim(min(x[:, 0, i]), max(x[:, 0, i]))
#       5     plt.xlabel('X-axis Label')
#
# IndexError: index 16 is out of bounds for axis 2 with size 16

# %%
for i in range(20):
# Plotting the line chart
    plt.plot(x[:, 0, i], marker='o', markersize=1)
    plt.ylim(min(x[:, 0, i]), max(x[:, 0, i]))
    plt.xlabel('X-axis Label')
    plt.ylabel('Y-axis Label', )
    plt.title(f'Bearing1-1 Feature {i+1}')
    # Display the plot
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_18813/19378523.py in <module>
#       1 for i in range(20):
#       2 # Plotting the line chart
# ----> 3     plt.plot(x[:, 0, i], marker='o', markersize=1)
#       4     plt.ylim(min(x[:, 0, i]), max(x[:, 0, i]))
#       5     plt.xlabel('X-axis Label')
#
# IndexError: index 16 is out of bounds for axis 2 with size 16

# %%
x = np.load(f'../../../data/10FEMTO/processed_data/Bearing1_1/Bearing1_1_train_X_1280.npy')
for i in range(20):
# Plotting the line chart
    plt.plot(x[:, 0, i], marker='o', markersize=1)
    plt.ylim(min(x[:, 0, i]), max(x[:, 0, i]))
    plt.xlabel('X-axis Label')
    plt.ylabel('Y-axis Label', )
    plt.title(f'Bearing1-1 Feature 1280 {i+1}')
    # Display the plot
    plt.show()

# %%
x = np.load(f'../../../data/10FEMTO/processed_data/Bearing1_1/Bearing1_1_train_X_640.npy')
for i in range(16):
# Plotting the line chart
    plt.plot(x[:, 0, i], marker='o', markersize=1)
    plt.ylim(min(x[:, 0, i]), max(x[:, 0, i]))
    plt.xlabel('X-axis Label')
    plt.ylabel('Y-axis Label', )
    plt.title(f'Bearing1-1 Feature 640 {i+1}')
    # Display the plot
    plt.show()

# %% [markdown]
# ### vibration data

# %%
import os
FEMTO = '../../../data/10FEMTO/raw_data/Validation_set/'
folder = 'Bearing1_4'
accs = os.listdir(FEMTO+folder)
accs.sort()
accs = [acc for acc in accs if acc.startswith('acc')]
y_list = []
for stamp, acc in enumerate(accs):
    x = pd.read_csv(f'{FEMTO}/{folder}/{acc}', header=None, sep=',', usecols=[4])
    x_avg = x.sum() / len(x)
    y_list.append(x_avg)
y_list = np.array(y_list)
print(y_list.shape)
plt.plot(y_list, marker='o', markersize=1)
plt.ylim(min(y_list), max(y_list))
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label', )
plt.title(f'Bearing1-1 Vibration')
# Display the plot
plt.show()
# Out:
# (1428, 1)

# %%
import os
FEMTO = '../../../data/10FEMTO/raw_data/Validation_set/'
folder = 'Bearing1_1'
accs = os.listdir(FEMTO+folder)
accs.sort()
accs = [acc for acc in accs if acc.startswith('acc')]
y_list = []
for stamp, acc in enumerate(accs):
    x = pd.read_csv(f'{FEMTO}/{folder}/{acc}', header=None, sep=',', usecols=[4])
    x_avg = x.sum() / len(x)
    y_list.append(x_avg)
y_list = np.array(y_list)
print(y_list.shape)
plt.plot(y_list, marker='o', markersize=1)
plt.ylim(min(y_list), max(y_list))
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label', )
plt.title(f'Bearing1-1 Vibration')
# Display the plot
plt.show()
# Out:
# (2803, 1)

# %% [markdown]
# ### Train Test Dataset Vibration Signal

# %%
def draw_vibration(FOLDERS: List[str], title: str):
    FEMTO = '../../../data/10FEMTO/raw_data/Validation_set/'
    ax: Axes3D = plt.figure().add_subplot(111, projection='3d', facecolor='w')
    for (i, folder) in enumerate(FOLDERS):
        accs = os.listdir(FEMTO+folder)
        accs.sort()
        accs = [acc for acc in accs if acc.startswith('acc')]
        y_list = []
        x_list = []
        for stamp, acc in enumerate(accs):
            x = pd.read_csv(f'{FEMTO}/{folder}/{acc}', header=None, sep=',', usecols=[4])
            # x_avg = x.sum() / len(x)
            # x_max = x.max()
            x_median = np.median(x)
            # sorted_data = np.sort(x)
            # x_34 = np.percentile(sorted_data, 75)
            y_list.append(x_median)
            x_list.append(stamp)
        y_list = np.array(y_list)
        y_list = y_list.reshape(-1)
        
        ax.plot(xs=x_list, ys=y_list, zs=-i, zdir='x', label='curve in (x, y)', linewidth=0.3)

    ax.set_xticks(np.arange(0, -len(FOLDERS), -1), labels=FOLDERS, rotation=45, horizontalalignment='right', verticalalignment='center_baseline')
    ax.set_xlim(-len(FOLDERS) + 1, 0)

    ax.set_ylabel('Time ($ 10^4$s)')
    ax.set_yticks(np.arange(0, 4000, 1000), labels=[f'{i}' for i in range(4)])
    ax.set_ylim(0, 3000)

    ax.set_zlabel('Vibration amplitudes(g)')
    ax.set_title(title, fontsize=18)
    plt.show()

# %%
TRAIN_DATASET = ['Bearing1_1', 'Bearing1_2', 'Bearing2_1', 'Bearing2_2', 'Bearing3_1', 'Bearing3_2']
draw_vibration(TRAIN_DATASET, 'Training data')

# %%
TEST_DATASET = ['Bearing1_3', 'Bearing1_4', 'Bearing1_5', 'Bearing1_6', 'Bearing1_7', \
            'Bearing2_3', 'Bearing2_4', 'Bearing2_5', 'Bearing2_6', 'Bearing2_7',\
            'Bearing3_3']
draw_vibration(TEST_DATASET, 'Testing data')

# %% [markdown]
# ### Feature Train Test Dataset

# %%
def draw_feature(FOLDERS: List[str], title: str):
    FEMTO = '../../../data/10FEMTO/raw_data/Validation_set/'
    for feature in range(16):
        ax: Axes3D = plt.figure().add_subplot(111, projection='3d', facecolor='w')
        for (i, folder) in enumerate(FOLDERS):
            x = np.load(f'../../../data/10FEMTO/processed_data/{folder}/{folder}_X_2560.npy')
            # min_val = np.min(x)
            # max_val = np.max(x)
            # normalized_data = (x - min_val) / (max_val - min_val)
            accs = os.listdir(FEMTO+folder)
            accs = [acc for acc in accs if acc.startswith('acc')]
            ax.plot(xs=[j for j in range(len(accs) - 40)], ys=x[:, 0, feature], zs=-i, zdir='x', label='curve in (x, y)', linewidth=0.3)

        ax.set_xticks(np.arange(0, -len(FOLDERS), -1), labels=FOLDERS, rotation=45, horizontalalignment='right', verticalalignment='center_baseline')
        ax.set_xlim(-len(FOLDERS) + 1, 0)

        ax.set_ylabel('Time ($ 10^4$s)')
        ax.set_yticks(np.arange(0, 4000, 1000), labels=[f'{i}' for i in range(4)])
        ax.set_ylim(0, 3000)

        ax.set_zlabel('Vibration amplitudes(g)')
        ax.set_title(f'{title} P{feature+1}', fontsize=18)
        plt.show()

# %%
TRAIN_DATASET = ['Bearing1_1', 'Bearing1_2', 'Bearing2_1', 'Bearing2_2', 'Bearing3_1', 'Bearing3_2']
draw_feature(TRAIN_DATASET, 'Training data')

# %%
TEST_DATASET = ['Bearing1_3', 'Bearing1_4', 'Bearing1_5', 'Bearing1_6', 'Bearing1_7', \
            'Bearing2_3', 'Bearing2_4', 'Bearing2_5', 'Bearing2_6', 'Bearing2_7',\
            'Bearing3_3']
draw_feature(TEST_DATASET, 'Testing data')

# %% [markdown]
# ### DL vs. TL HI Index

# %%
def dl_tl_hi(np_path, TEST_DATASET, PRETRAIN, FINETUNE, y):
    hi = np.load(f'../../../data/10FEMTO/processed_data/{y}/{y}_Y.npy')
    hi_dl = np.load(f'{np_path}/{FINETUNE}_pretrain_7_{TEST_DATASET}.npy')
    hi_tl = np.load(f'{np_path}/{PRETRAIN}_pretrain_{FINETUNE}_finetune_7_{TEST_DATASET}.npy')
    plt.plot(hi_dl, linewidth=0.7, label='DL')
    plt.plot(hi_tl, linewidth=0.7, label='TL')
    plt.plot(hi, linewidth=0.7, label='Desired Response', linestyle='--')
    plt.legend()
    plt.xlabel('Time (s)')
    plt.ylabel('Health Index HI')
    plt.title(rf'{TEST_DATASET} $\rightarrow$ {PRETRAIN}')
    plt.xlim(0, len(hi))
    plt.ylim(0, 1)
    plt.show()

# %%
TEST_DATASET = 'Bearing1_4'
PRETRAIN = 'Bearing3'
FINETUNE = 'Bearing1'
dl_tl_hi('../../../data/np/', TEST_DATASET, PRETRAIN, FINETUNE, TEST_DATASET)

# %% [markdown]
# ### One Vibration test

# %%
FEMTO = '../../../data/10FEMTO/raw_data/Validation_set/'
folder = 'Bearing1_2'
accs = os.listdir(FEMTO+folder)
accs.sort()
accs = [acc for acc in accs if acc.startswith('acc')]
y_list = []
x_list = []
for stamp, acc in enumerate(accs):
    x = pd.read_csv(f'{FEMTO}/{folder}/{acc}', header=None, sep=',', usecols=[4])
    # x_avg = x.sum() / len(x)
    x_median = np.median(x)
    # sorted_data = np.sort(x)
    # x_34 = np.percentile(sorted_data, 75)
    # x_max = x.max()
    y_list.append(x_median)
    x_list.append(stamp)
y_list = np.array(y_list)
y_list = y_list.reshape(-1)
ax = plt.figure().add_subplot(111, projection='3d')
# scale
x_scale=1
y_scale=2
z_scale=1

scale=np.diag([x_scale, y_scale, z_scale, 1.0])
scale=scale*(1.0/scale.max())
scale[3,3]=1.0

def short_proj():
  return np.dot(Axes3D.get_proj(ax), scale)

ax.get_proj=short_proj
# scale done
ax.plot(xs=x_list, ys=y_list, zs=0, zdir='x', label='curve in (x, y)', linewidth='0.5')
ax.set_xticks(np.arange(0, -6, -1), labels=['Bearing1_1', 'Bearing1_2', 'Bearing2_1', 'Bearing2_2', 'Bearing3_1', 'Bearing3_2'], rotation=45, horizontalalignment='right', verticalalignment='center_baseline')
ax.set_xlim(-5, 0)

ax.set_ylabel('Time ($ 10^4$s)')
ax.set_yticks(np.arange(0, 4000, 1000), labels=[f'{i}' for i in range(4)])
ax.set_ylim(0, 3000)

ax.set_zlabel('Vibration amplitudes(g)')
ax.set_zlim(min(y_list), max(y_list))
ax.set_title('One Test', fontsize=18)
plt.show()

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D
from mpl_toolkits.mplot3d import proj3d

import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt

mpl.rcParams['legend.fontsize'] = 10

fig = plt.figure(figsize=(5,5))
ax = fig.gca(projection='3d')
theta = np.linspace(-4 * np.pi, 4 * np.pi, 100)
z = np.linspace(-2, 2, 100)
r = z**2 + 1
x = r * np.sin(theta)
y = r * np.cos(theta)


"""                                                                                                                                                    
Scaling is done from here...                                                                                                                           
"""
x_scale=1
y_scale=3
z_scale=1

scale=np.diag([x_scale, y_scale, z_scale, 1.0])
scale=scale*(1.0/scale.max())
scale[3,3]=1.0

def short_proj():
  return np.dot(Axes3D.get_proj(ax), scale)

ax.get_proj=short_proj
"""                                                                                                                                                    
to here                                                                                                                                                
"""

ax.plot(z, y, x, label='parametric curve')
ax.legend()

plt.show()
# Out:
# /home/kai/anaconda3/envs/nlp/lib/python3.7/site-packages/ipykernel_launcher.py:11: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   # This is added back by InteractiveShellApp.init_path()
